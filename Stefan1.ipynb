# %%
# read data file from file data

import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./Data/kitCapstoneJan24_data.csv',sep=';')

# %%
data.head(20)
# Out:
#     month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 0       1   Country A                                              296.0
# 1       2   Country A                                              414.0
# 2       3   Country A                                              405.0
# 3       4   Country A                                              359.0
# 4       5   Country A                                              403.0
# 5       6   Country A                                              196.0
# 6       7   Country A                                              387.0
# 7       8   Country A                                              281.0
# 8       9   Country A                                              246.0
# 9      10   Country A                                              290.0
# 10     11   Country A                                              310.0
# 11     12   Country A                                              189.0
# ...

# %%
# write a function to only consider the rows with countryname = CountryA
def countryA(data):
    return data[data['countryname'] == 'Country A']

# %%
countryA(data).head(20)
# Out:
#     month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 0       1   Country A                                              296.0
# 1       2   Country A                                              414.0
# 2       3   Country A                                              405.0
# 3       4   Country A                                              359.0
# 4       5   Country A                                              403.0
# 5       6   Country A                                              196.0
# 6       7   Country A                                              387.0
# 7       8   Country A                                              281.0
# 8       9   Country A                                              246.0
# 9      10   Country A                                              290.0
# 10     11   Country A                                              310.0
# 11     12   Country A                                              189.0
# ...

# %%
# give number of rows with sales_actuals_monthly__vehiclegroup01__retail = NaN
def NaN(data):
    return data[data['sales_actuals_monthly__vehiclegroup01__retail'].isnull()]

# %%
NaN(countryA(data))
# Out:
#      month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 258    259   Country A                                                NaN
# 259    260   Country A                                                NaN
# 260    261   Country A                                                NaN
# 261    262   Country A                                                NaN
# 262    263   Country A                                                NaN
# ..     ...         ...                                                ...
# 355    356   Country A                                                NaN
# 356    357   Country A                                                NaN
# 357    358   Country A                                                NaN
# 358    359   Country A                                                NaN
# 359    360   Country A                                                NaN
#
#      sales_actuals_monthly__vehiclegroup01__retail  \
# ...

# %%
# plot sales_actuals_monthly__vehiclegroup01__orderintake over month for Country A
import matplotlib.pyplot as plt
plt.plot(countryA(data)['sales_actuals_monthly__vehiclegroup01__orderintake'])
plt.show()

# %%
# drop all columns which have vehiclegroup in the name except vehiclegroup01
def drop(data):
    return data.drop(data.columns[data.columns.str.contains('vehiclegroup')], axis=1)
