# %%
# read data file from file data

import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./Data/kitCapstoneJan24_data.csv',sep=';')

# %%
data.head(20)
# Out:
#     month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 0       1   Country A                                              296.0
# 1       2   Country A                                              414.0
# 2       3   Country A                                              405.0
# 3       4   Country A                                              359.0
# 4       5   Country A                                              403.0
# 5       6   Country A                                              196.0
# 6       7   Country A                                              387.0
# 7       8   Country A                                              281.0
# 8       9   Country A                                              246.0
# 9      10   Country A                                              290.0
# 10     11   Country A                                              310.0
# 11     12   Country A                                              189.0
# ...

# %%
# write a function to only consider the rows with countryname = CountryA
def countryA(data):
    return data[data['countryname'] == 'Country A']

# %%
countryA(data).head(20)
# Out:
#     month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 0       1   Country A                                              296.0
# 1       2   Country A                                              414.0
# 2       3   Country A                                              405.0
# 3       4   Country A                                              359.0
# 4       5   Country A                                              403.0
# 5       6   Country A                                              196.0
# 6       7   Country A                                              387.0
# 7       8   Country A                                              281.0
# 8       9   Country A                                              246.0
# 9      10   Country A                                              290.0
# 10     11   Country A                                              310.0
# 11     12   Country A                                              189.0
# ...

# %%
# give number of rows with sales_actuals_monthly__vehiclegroup01__retail = NaN
def NaN(data):
    return data[data['sales_actuals_monthly__vehiclegroup01__retail'].isnull()]

# %%
NaN(countryA(data))
# Out:
#      month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 258    259   Country A                                                NaN
# 259    260   Country A                                                NaN
# 260    261   Country A                                                NaN
# 261    262   Country A                                                NaN
# 262    263   Country A                                                NaN
# ..     ...         ...                                                ...
# 355    356   Country A                                                NaN
# 356    357   Country A                                                NaN
# 357    358   Country A                                                NaN
# 358    359   Country A                                                NaN
# 359    360   Country A                                                NaN
#
#      sales_actuals_monthly__vehiclegroup01__retail  \
# ...

# %%
# plot sales_actuals_monthly__vehiclegroup01__orderintake over month for Country A
import matplotlib.pyplot as plt
plt.plot(countryA(data)['sales_actuals_monthly__vehiclegroup01__orderintake'])
plt.show()

# %%
# drop all columns which have vehiclegroup in the name except vehiclegroup01
def drop(data):
    return data.drop(data.columns[data.columns.str.contains('vehiclegroup')], axis=1)

# %% [markdown]
# ## SARIMAX model

# %%
df_a = countryA(data)
df_a.head(20)
# Out:
#     month countryname  sales_actuals_monthly__vehiclegroup01__orderintake  \
# 0       1   Country A                                              296.0
# 1       2   Country A                                              414.0
# 2       3   Country A                                              405.0
# 3       4   Country A                                              359.0
# 4       5   Country A                                              403.0
# 5       6   Country A                                              196.0
# 6       7   Country A                                              387.0
# 7       8   Country A                                              281.0
# 8       9   Country A                                              246.0
# 9      10   Country A                                              290.0
# 10     11   Country A                                              310.0
# 11     12   Country A                                              189.0
# ...

# %%
# create data frame with month and sales_actuals_monthly__vehiclegroup01__orderintake
df_a01 = df_a[['month','sales_actuals_monthly__vehiclegroup01__orderintake']]

# df_a01 als time series
df_a01 = df_a01.set_index('month')
df_a01.head(20)
# Out:
#        sales_actuals_monthly__vehiclegroup01__orderintake
# month
# 1                                                  296.0
# 2                                                  414.0
# 3                                                  405.0
# 4                                                  359.0
# 5                                                  403.0
# 6                                                  196.0
# 7                                                  387.0
# 8                                                  281.0
# 9                                                  246.0
# 10                                                 290.0
# 11                                                 310.0
# 12                                                 189.0
# 13                                                 353.0
# 14                                                 361.0
# 15                                                 322.0
# ...

# %%
#  plot time series
plt.plot(df_a01)
plt.show()

# %% [markdown]
# ### Trend?

# %%
# delete rows after month 258
df_a01 = df_a01[df_a01.index <= 258]

# %%
# missing values in time series?
df_a01.isnull().sum()
# Out:
# sales_actuals_monthly__vehiclegroup01__orderintake    0
# dtype: int64

# %%
# dickey fuller test
from statsmodels.tsa.stattools import adfuller

adf = adfuller(df_a01['sales_actuals_monthly__vehiclegroup01__orderintake'])
print('ADF Statistic: %f' % adf[0])
print('p-value: %f' % adf[1])
# hypotheses
# H0: time series is not stationary
# H1: time series is stationary
# p-value > 0.05 -> H0 cannot be rejected -> time series is not stationary
# here: time series is stationary
# Out:
# ADF Statistic: -3.120375
# p-value: 0.025082

# %%
# kpss test for stationarity
from statsmodels.tsa.stattools import kpss

kpsstest = kpss(df_a01['sales_actuals_monthly__vehiclegroup01__orderintake'], regression='c')
print('KPSS Statistic: %f' % kpsstest[0])
print('p-value: %f' % kpsstest[1])
# hypotheses
# H0: time series is stationary
# H1: time series is not stationary
# here: time series is stationary
# Out:
# KPSS Statistic: 0.188633
# p-value: 0.100000
# /var/folders/0b/mskprp0n5rl3kmdxqnhgm_980000gn/T/ipykernel_31082/4066925027.py:4: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpsstest = kpss(df_a01['sales_actuals_monthly__vehiclegroup01__orderintake'], regression='c')

# %% [markdown]
# ### Seasonality

# %%
# acf and pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

plot_acf(df_a01)
plt.show()

plot_pacf(df_a01)
plt.show()

# %% [markdown]
# --> yearly seasonality
# -> diff(12)

# %%
# differencing with lag 12
df_a01_diff = df_a01.diff(periods=12)

# %%
# plot differenced time series
plt.plot(df_a01_diff)

# %%
df_a01_diff.head(20)
# Out:
#        sales_actuals_monthly__vehiclegroup01__orderintake
# month
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                  57.0
# 14                                                 -53.0
# 15                                                 -83.0
# ...

# %%
# delete rows with NaN
df_a01_diff = df_a01_diff.dropna()

# %%
df_a01_diff.head(20)
# Out:
#        sales_actuals_monthly__vehiclegroup01__orderintake
# month
# 13                                                  57.0
# 14                                                 -53.0
# 15                                                 -83.0
# 16                                                 -65.0
# 17                                                 -98.0
# 18                                                  42.0
# 19                                                  95.0
# 20                                                 154.0
# 21                                                 178.0
# 22                                                 143.0
# 23                                                  60.0
# 24                                                 135.0
# 25                                                  37.0
# 26                                                  -1.0
# 27                                                  12.0
# ...

# %%
# acf and pacf of differenced time series
plot_acf(df_a01_diff)
plt.show()

# %%
# pacf
plot_pacf(df_a01_diff)
plt.show()

# %%
# perform differencing again
df_a01_diff2 = df_a01_diff.diff(periods=12)

# remove rows with NaN
df_a01_diff2 = df_a01_diff2.dropna()

# acf and pacf of differenced time series
plot_acf(df_a01_diff2)
plt.show()

plot_pacf(df_a01_diff2)
plt.show()

# %% [markdown]
# ## Model

# %%
from sklearn.inspection import permutation_importance
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits=4, gap=6, test_size=18)

for i, (train_index, test_index) in enumerate(tscv.split(X_in, y)):
    X_train, y_val = df_a01.iloc[train_index], df_a01.iloc[test_index]
